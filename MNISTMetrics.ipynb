# %%
# %matplotlib notebook

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

metrics = pd.read_csv('metrics.csv', index_col=0)
metrics
# Out:
#    epoch_losses  elapsed_time
# 0      2.285699      2.962703
# 1      2.259833      5.880651
# 2      2.293505      8.798181
# 3      2.270942     11.672457
# 4      2.302739     14.595067
# 5      2.302785     17.481792
# 6      2.302787     20.394744
# 7      2.302787     23.300348
# 8      2.302787     26.289638
# 9      2.302787     29.166903

# %%
metrics2 = pd.read_csv('metrics.ppn2.csv', index_col=0)
plt.figure()
plt.plot(metrics.elapsed_time, metrics.epoch_losses, label='PPN 10')
plt.plot(metrics2.elapsed_time, metrics2.epoch_losses, label='PPN 2')
plt.xlabel('Elapsed Time')
plt.ylabel('Training Losss')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(metrics.epoch_losses, label='PPN 10')
plt.plot(metrics2.epoch_losses, label='PPN 2')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
